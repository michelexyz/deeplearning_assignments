# %%
import vugrad as vg

# %%
from train_mlp_RELU import MLP, MLPReLU, train_mlp

# %%
val_accuracies, train_losses, model = train_mlp(batch_size=128, epochs=10, lr= 0.0001, data_name='mnist', mlp_class=MLP)
# Out:
# ## loaded data:
#          number of instances: 55000 in training, 5000 in validation
#  training class distribution: [5434 6212 5465 5622 5343 4963 5436 5702 5357 5466]
#      val. class distribution: [489 530 493 509 499 458 482 563 494 483]
#
# ## Starting training
# epoch 000
#        accuracy: 0.1042
#    running loss: 0.4015
# epoch 001
#        accuracy: 0.947
#    running loss: 0.2106
# epoch 002
#        accuracy: 0.9546
#    running loss: 0.1589
# epoch 003
#        accuracy: 0.961
#    running loss: 0.1263
# epoch 004
#        accuracy: 0.9646
#    running loss: 0.1023
# epoch 005
#        accuracy: 0.9656
#    running loss: 0.08433
# epoch 006
#        accuracy: 0.9666
#    running loss: 0.07018
# epoch 007
#        accuracy: 0.9684
#    running loss: 0.05922
# epoch 008
#        accuracy: 0.9704
#    running loss: 0.05052
# epoch 009
#        accuracy: 0.9704
#    running loss: 0.04381

# %%
val_accuracies_sig, train_losses_sig, model_sig = train_mlp(batch_size=128, epochs=10, lr= 0.001, data_name='mnist', mlp_class=MLPReLU)
# Out:
# ## loaded data:
#          number of instances: 55000 in training, 5000 in validation
#  training class distribution: [5434 6212 5465 5622 5343 4963 5436 5702 5357 5466]
#      val. class distribution: [489 530 493 509 499 458 482 563 494 483]
#
# ## Starting training
# epoch 000
#        accuracy: 0.1408
#    running loss: 7.647e+09
# epoch 001
#        accuracy: 0.1018
#    running loss: 481.7
# epoch 002
#        accuracy: 0.1058
#    running loss: 2.301
# epoch 003
#        accuracy: 0.1058
#    running loss: 2.301
# epoch 004
#        accuracy: 0.1058
#    running loss: 2.301
# epoch 005
#        accuracy: 0.1058
#    running loss: 2.301
# epoch 006
#        accuracy: 0.1058
#    running loss: 2.301
# epoch 007
#        accuracy: 0.1058
#    running loss: 2.301
# epoch 008
#        accuracy: 0.1058
#    running loss: 2.301
# epoch 009
#        accuracy: 0.1058
#    running loss: 2.301

# %%
# Plot the results

import matplotlib.pyplot as plt

plt.plot(val_accuracies, label='ReLU')

plt.plot(val_accuracies_sig, label='Sigmoid')

plt.xlabel('Epoch')

plt.ylabel('Validation Accuracy')

plt.legend()

plt.show()

# %%
# plot the training losses

plt.plot(train_losses, label='ReLU')

plt.plot(train_losses_sig, label='Sigmoid')

plt.xlabel('Epoch')

plt.ylabel('Training Loss')

plt.legend()

plt.show()

# %%
dummy_input = vg.randn(1, 784)
